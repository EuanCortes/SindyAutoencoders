# %%
import pickle

# Load the contents of the pkl file
with open('experiment_results_202504240936.pkl', 'rb') as file:
    experiment_results = pickle.load(file)

# Display the loaded data
print(experiment_results)
# Out:
#    num_epochs    x_norm  sindy_predict_norm_x  \
# 0           1  0.176081              8.642532
#
#                                   sindy_coefficients    loss_decoder  \
# 0  [[0.31428444, 0.13756578, 0.35387355], [0.3481...  tensor(0.0166)
#
#   loss_decoder_sindy  loss_sindy loss_sindy_regularization  \
# 0     tensor(8.6425)  tensor(0.)            tensor(0.2726)
#
#                                    validation_losses sindy_model_terms  ...  \
# 0  [[0.028307711705565453, 0.0, 8.642532348632812...            [60.0]  ...
#
#      widths  epoch_size  batch_size  learning_rate  \
# 0  [64, 32]      256000        1024          0.001
#
#                                            data_path  print_progress  \
# 0  /Users/euan/Documents/DTU/Masters/Semester 3/D...            True
#
#    print_frequency  max_epochs  refinement_epochs  \
# 0                1           3                  2
#
#                            save_name
# 0  lorenz_2025_04_24_09_27_11_493189
#
# ...
